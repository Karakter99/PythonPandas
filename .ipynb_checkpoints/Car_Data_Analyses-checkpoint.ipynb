# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###CAR DATA ANALYSES

# %%
data = pd.read_csv("CarsData.csv")
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %%
data.shape
# Out:
# (432, 15)

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (426, 15)

# %%
data["Make"].value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Subaru           11
# Pontiac          11
# Lexus            11
# Kia              11
# Lincoln           9
# Buick             9
# Mazda             9
# Mercury           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %%
data[(data["Make"]== "Volkswagen") &(data["Type"]== "Sedan")]
# Out:
#            Make                           Model   Type  Origin DriveTrain  \
# 406  Volkswagen                    Golf GLS 4dr  Sedan  Europe      Front
# 407  Volkswagen              GTI 1.8T 2dr hatch  Sedan  Europe      Front
# 408  Volkswagen               Jetta GLS TDI 4dr  Sedan  Europe      Front
# 409  Volkswagen         New Beetle GLS 1.8T 2dr  Sedan  Europe      Front
# 410  Volkswagen               Jetta GLI VR6 4dr  Sedan  Europe      Front
# 411  Volkswagen  New Beetle GLS convertible 2dr  Sedan  Europe      Front
# 412  Volkswagen                  Passat GLS 4dr  Sedan  Europe      Front
# 413  Volkswagen       Passat GLX V6 4MOTION 4dr  Sedan  Europe      Front
# 414  Volkswagen           Passat W8 4MOTION 4dr  Sedan  Europe      Front
# 415  Volkswagen                     Phaeton 4dr  Sedan  Europe      Front
# 416  Volkswagen                 Phaeton W12 4dr  Sedan  Europe      Front
#
#          MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# ...

# %%
data[data["Origin"].isin(["Europe","Asia"])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data=data[~(data["Weight"]>4000)]

# %%
data[data["Weight"]>4000]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Type, Origin, DriveTrain, MSRP, Invoice, EngineSize, Cylinders, Horsepower, MPG_City, MPG_Highway, Weight, Wheelbase, Length]
# Index: []

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data["MPG_City"]=data["MPG_City"] +3
# Out:
# /var/folders/bk/pk958r4s279f8bsyxc36_6800000gn/T/ipykernel_44882/2944491792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["MPG_City"]=data["MPG_City"] +3

# %%
# Out:
# 1      27.0
# 2      25.0
# 3      23.0
# 4      21.0
# 5      21.0
#        ...
# 427    24.0
# 428    23.0
# 429    22.0
# 430    25.0
# 431    23.0
# Name: MPG_City, Length: 323, dtype: float64
